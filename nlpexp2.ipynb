# %% [markdown]
# <a href="https://colab.research.google.com/github/ananxa/NLP-LAB1/blob/main/nlpexp2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import csv

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-96a23df1-6cb2-436e-975c-f8477a4164c6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-96a23df1-6cb2-436e-975c-f8477a4164c6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
lines = text.splitlines()
output = pd.DataFrame(lines, columns=['Content'])
output
# Out:
#                                               Content
# 0                              Random Thoughts Dump 🌱
# 1
# 2   Life update: nobody really knows what they’re ...
# 3   the plot twist. Some days you’re productive. S...
# 4               doing absolutely nothing. Both count.
# 5
# 6   Reminder: - Drink water. - Stop comparing your...
# 7   someone else’s highlight reel. - Start before ...
# 8
# 9   If you’re reading this, consider it a soft pus...
# 10  you’ve been overthinking. Progress > perfectio...
# 11
# 12                                       End of file.

# %%
with open('/content/Random Thoughts_text_file.txt','r',encoding='utf-8') as f:
  text=f.read()
  print(text)
# Out:
# Random Thoughts Dump 🌱
#
# Life update: nobody really knows what they’re doing, and that’s kind of
# the plot twist. Some days you’re productive. Some days you romanticize
# doing absolutely nothing. Both count.
#
# Reminder: - Drink water. - Stop comparing your behind-the-scenes to
# someone else’s highlight reel. - Start before you feel ready.
#
# If you’re reading this, consider it a soft push to do that one thing
# you’ve been overthinking. Progress > perfection. Always.
#
# End of file.

# %%
with open('/content/students_marks.csv','r',encoding='utf-8') as f:
  text=f.read()
  print(text)
# Out:
# Marks
# 85
# 90
# 78
# 90
# 0
# 85

# %%
# !pip install PyPDF2

import PyPDF2
pdf_file=open('/content/nlp_pdf_file.pdf','rb')
pdf_reader=PyPDF2.PdfReader(pdf_file)
text = ""
for page in pdf_reader.pages:
  text += page.extract_text()
print(text)
pdf_file.close()
# Out:
# ...
# Random Life Notes ■
#
# This is a completely random PDF. No agenda. No pressure. Just vibes.
# Some days you win. Some days you learn. Both are valid.
# If you’re reading this, take it as a sign to keep going—even if things feel messy right now.
# You don’t need everything figured out. Start anyway.
# End of random document. ■
